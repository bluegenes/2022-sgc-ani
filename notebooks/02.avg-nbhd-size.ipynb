# %%
import pandas as pd

# %%
nbhd_describe = "2020-ibd-nbhds.contigs.sig.describe.csv"
nDF = pd.read_csv(nbhd_describe)
nDF.head()
# Out:
#                                       signature_file  \
# 0  /group/ctbrowngrp2/tereiter/github/2020-ibd/ou...
# 1  /group/ctbrowngrp2/tereiter/github/2020-ibd/ou...
# 2  /group/ctbrowngrp2/tereiter/github/2020-ibd/ou...
# 3  /group/ctbrowngrp2/tereiter/github/2020-ibd/ou...
# 4  /group/ctbrowngrp2/tereiter/github/2020-ibd/ou...
#
#                                 md5  ksize moltype  num  scaled  n_hashes  \
# 0  3ea79a88e3c54ef987176b26373053df     31     DNA    0    1000      4803
# 1  b2acf34dde85a950a9e0d082f1bc38b4     31     DNA    0    1000      1122
# 2  5400ae2dbc3b32fbea9b5211b19425ee     31     DNA    0    1000      2574
# 3  4c1e5948633b39f1500d526a025907e8     31     DNA    0    1000      2324
# 4  83450f8978d1fcfef86770d04ea80e33     31     DNA    0    1000      2287
#
#    seed  with_abundance                                               name  \
# 0    42               0  nbhd:FP929033.1 Bacteroides xylanisolvens XB1A...
# ...

# %%
nDF['n_hashes'].describe().reset_index().set_index("index")
# Out:
#            n_hashes
# index
# count  32670.000000
# mean    1483.321151
# std     1454.837159
# min        0.000000
# 25%      339.000000
# 50%      984.000000
# 75%     2333.000000
# max    18667.000000
